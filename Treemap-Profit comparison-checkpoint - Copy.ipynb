# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv(r"C:\Users\nblsh\Downloads\product_profits.csv", encoding = 'latin1')

df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  Product Price  Sales Volume    sales  \
# 0        10107               30          95.70             2  2871.00
# 1        10121               34          81.35             5  2765.90
# 2        10134               41          94.74             2  3884.34
# 3        10145               45          83.26             6  3746.70
# 4        10159               49         100.00            14  5205.27
#
#                date   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...          NaN
# 1  05-07-2003 00:00  Shipped       2         5     2003  ...          NaN
# 2  07-01-2003 00:00  Shipped       3         7     2003  ...          NaN
# 3    8/25/2003 0:00  Shipped       3         8     2003  ...          NaN
# 4  10-10-2003 00:00  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY Region CONTACTLASTNAME  \
# ...
