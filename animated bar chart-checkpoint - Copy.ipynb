# %%
# !pip install bar_chart_race pandas
# Out:
# ...
#      ------------------------------------ 156.8/156.8 kB 722.1 kB/s eta 0:00:00
# ...

# %%
import pandas as pd
import bar_chart_race as bcr

# %%
df = pd.read_csv(r"C:\Users\nblsh\Downloads\market_trends.csv", index_col =0, parse_dates =True)

# %%
bcr.bar_chart_race(df=df,
                  filename=None,
                  orientation='h',
                  sort='desc',
                  n_bars=5,
                  fixed_order=False,
                  fixed_max=True,
                  steps_per_period=20,
                  interpolate_period=True,
                  period_length=1500,
                  period_fmt='%b &Y',
                  title='Market Share Trends Over Time',
                  bar_size=0.95,
                  cmap='dark12'
                  )
# Out:
# C:\Users\nblsh\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\nblsh\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="944" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
